# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('trees.csv')
df.head()
# Out:
#    tree_id    legal_status                                species  \
# 0    99001  DPW Maintained  Lophostemon confertus :: Brisbane Box
# 1   253633  DPW Maintained  Tristaniopsis laurina :: Swamp Myrtle
# 2    96059  Permitted Site      Afrocarpus gracilior :: Fern Pine
# 3    37613  DPW Maintained  Tristaniopsis laurina :: Swamp Myrtle
# 4    64585  Permitted Site       Ginkgo biloba :: Maidenhair Tree
#
#                 address  site_order                     site_info  \
# 0  2190X North Point St         7.0  Sidewalk: Curb side : Cutout
# 1         1909 Judah St         1.0  Sidewalk: Curb side : Cutout
# 2       101 Montcalm St         1.0  Sidewalk: Curb side : Cutout
# 3          423 17th Ave         1.0  Sidewalk: Curb side : Cutout
# 4          3370 22nd St         1.0  Sidewalk: Curb side : Cutout
#
#              caretaker        date  dbh plot_size   latitude   longitude
# 0  DPW for City Agency  2011-04-18  NaN       3x3  37.802851 -122.443247
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tree_id       10000 non-null  int64
#  1   legal_status  9994 non-null   object
#  2   species       10000 non-null  object
#  3   address       9937 non-null   object
#  4   site_order    9827 non-null   float64
#  5   site_info     10000 non-null  object
#  6   caretaker     10000 non-null  object
#  7   date          10000 non-null  object
#  8   dbh           6346 non-null   float64
#  9   plot_size     4863 non-null   object
#  10  latitude      9875 non-null   float64
#  11  longitude     9875 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 937.6+ KB

# %%
df.describe()
# Out:
#              tree_id   site_order          dbh     latitude    longitude
# count   10000.000000  9827.000000  6346.000000  9875.000000  9875.000000
# mean    65846.831900     2.669482     6.307595    37.758804  -122.435381
# std     50011.511981     4.400961     5.699869     0.024548     0.031108
# min         2.000000     1.000000     0.000000    37.509004  -122.511257
# 25%     35563.500000     1.000000     3.000000    37.738818  -122.457126
# 50%     52127.500000     1.000000     4.000000    37.760479  -122.430794
# 75%     86524.000000     3.000000     8.000000    37.778076  -122.412354
# max    261540.000000   111.000000    80.000000    37.808912  -122.368651

# %%
plt.rcParams["figure.figsize"]=(18,10)

df.dbh.plot.kde()
plt.show()
plt.clf()
df.dbh.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_grouped=df.groupby('dbh').count()
df_grouped["tree_id"].sum()
# Out:
# 6346

# %%
df_grouped
# Out:
#       tree_id  legal_status  species  address  site_order  site_info  \
# dbh
# 0.0        44            44       44       44          44         44
# 1.0       154           154      154      154         152        154
# 2.0       229           229      229      229         228        229
# 3.0      2721          2718     2721     2721        2668       2721
# 4.0       319           319      319      319         318        319
# 5.0       324           324      324      324         319        324
# 6.0       601           599      601      601         596        601
# 7.0       227           227      227      227         227        227
# 8.0       269           269      269      269         266        269
# 9.0       173           173      173      173         172        173
# 10.0      197           197      197      197         196        197
# 11.0      112           112      112      112         111        112
# ...

# %%
df_grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 43 entries, 0.0 to 80.0
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   tree_id       43 non-null     int64
#  1   legal_status  43 non-null     int64
#  2   species       43 non-null     int64
#  3   address       43 non-null     int64
#  4   site_order    43 non-null     int64
#  5   site_info     43 non-null     int64
#  6   caretaker     43 non-null     int64
#  7   date          43 non-null     int64
#  8   plot_size     43 non-null     int64
#  9   latitude      43 non-null     int64
#  10  longitude     43 non-null     int64
# dtypes: int64(11)
# memory usage: 4.0 KB

# %%
sns.countplot(df["dbh"])
# Out:
# c:\Users\LENOVO\anaconda3\envs\streamlit-lottie\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='dbh', ylabel='count'>

# %%
# check missing values
df.isnull().sum()
# Out:
# tree_id            0
# legal_status       6
# species            0
# address           63
# site_order       173
# site_info          0
# caretaker          0
# date               0
# dbh             3654
# plot_size       5137
# latitude         125
# longitude        125
# dtype: int64

# %%
df.dropna(subset=['longitude', 'latitude']) # drop rows with missing values in the longitude and latitude columns
# Out:
#       tree_id    legal_status                                     species  \
# 0       99001  DPW Maintained       Lophostemon confertus :: Brisbane Box
# 1      253633  DPW Maintained       Tristaniopsis laurina :: Swamp Myrtle
# 2       96059  Permitted Site           Afrocarpus gracilior :: Fern Pine
# 3       37613  DPW Maintained       Tristaniopsis laurina :: Swamp Myrtle
# 4       64585  Permitted Site            Ginkgo biloba :: Maidenhair Tree
# ...       ...             ...                                         ...
# 9995    29692  DPW Maintained       Lophostemon confertus :: Brisbane Box
# 9996    53666  DPW Maintained         Pyrus calleryana :: Ornamental Pear
# 9997   254527  DPW Maintained  Arbutus 'Marina' :: Hybrid Strawberry Tree
# 9998    31941  DPW Maintained         Cordyline australis :: Dracena Palm
# 9999    57316  DPW Maintained                  Ceratonia siliqua :: Carob
#
#                    address  site_order                     site_info  \
# ...
